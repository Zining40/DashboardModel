# %%
# Get the requirements of a package

import json
import requests

package_name = 'prophet'
url = 'https://pypi.python.org/pypi/' + str(package_name) + '/json'
data = requests.get(url).json()

print(data['info']['requires_dist'])
# Out:
# ['cmdstanpy (>=1.0.4)', 'numpy (>=1.15.4)', 'matplotlib (>=2.0.0)', 'pandas (>=1.0.4)', 'LunarCalendar (>=0.0.9)', 'convertdate (>=2.1.2)', 'holidays (>=0.25)', 'python-dateutil (>=2.8.0)', 'tqdm (>=4.36.1)', 'importlib-resources', "setuptools (>=64) ; extra == 'dev'", "wheel ; extra == 'dev'", "pytest ; extra == 'dev'", "jupyterlab ; extra == 'dev'", "nbconvert ; extra == 'dev'", "plotly ; extra == 'dev'", "dask[dataframe] ; extra == 'parallel'", "distributed ; extra == 'parallel'"]

# %%
import pandas as pd
from prophet import Prophet

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet()
m.fit(df)
# Out:
# 00:12:50 - cmdstanpy - INFO - Chain [1] start processing
# 00:12:51 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.200123    7.446765    8.953338
# 3266 2017-01-16  8.525119    7.785975    9.220045
# 3267 2017-01-17  8.312512    7.558594    9.009544
# 3268 2017-01-18  8.145089    7.362719    8.901526
# 3269 2017-01-19  8.156982    7.373797    8.921134

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)

# %%
plot_components_plotly(m, forecast)

# %%
import sys
sys.path
# Out:
# ['/Users/zining/Desktop/112-1/實習/Prophet',
#  '/opt/anaconda3/envs/prophet/lib/python310.zip',
#  '/opt/anaconda3/envs/prophet/lib/python3.10',
#  '/opt/anaconda3/envs/prophet/lib/python3.10/lib-dynload',
#  '',
#  '/opt/anaconda3/envs/prophet/lib/python3.10/site-packages']

# %%
import sys
sys.path
# Out:
# ['/Users/zining/Desktop/112-1/實習/Prophet',
#  '/opt/anaconda3/lib/python38.zip',
#  '/opt/anaconda3/lib/python3.8',
#  '/opt/anaconda3/lib/python3.8/lib-dynload',
#  '',
#  '/opt/anaconda3/lib/python3.8/site-packages',
#  '/opt/anaconda3/lib/python3.8/site-packages/aeosa',
#  '/opt/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg',
#  '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/zining/.ipython']
